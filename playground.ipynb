# %%
import yaml
import requests
from math import inf
from time import time
from os.path import join, dirname, exists
from os import environ, makedirs
from operator import itemgetter


WILDCARDS_DIR = environ.get("WILDCARDS_DIR", "")
CHARACTERS_WILDCARD_PATH = join(WILDCARDS_DIR, "characters.yaml")
POPULAR_WILDCARD_PATH = join(WILDCARDS_DIR, "popular.yaml")

# %%
def get_tags(copyright: str, page_no: int) -> list[str]:
    """Get tag information from Danbooru webpage"""
    base_url = "https://danbooru.donmai.us/tags.json"
    queries = [
        "commit=Search",
        f"page={page_no}",
        "search[category]=4",  # 4: character
        "search[has_wiki_page]=yes",  # Only tags with wiki pages
        "search[hide_empty]=yes",
        f"search[name_or_alias_matches]=*({copyright})",
        "search[order]=count",
    ]
    joined_query = "&".join(queries)
    url = f"{base_url}?{joined_query}"
    response = requests.get(url)
    response.raise_for_status()
    tag_infos = response.json()

    # Select only tag name and post count
    return list(map(itemgetter("name"), tag_infos))


def get_related_tags(tag: str) -> list[dict]:
    """Get related tag information from Danbooru webpage"""
    base_url = "https://danbooru.donmai.us/related_tag.json"
    queries = [
        "commit=Search",
        "search[category]=General",
        f"search[query]={tag}",
    ]
    joined_query = "&".join(queries)
    url = f"{base_url}?{joined_query}"
    response = requests.get(url)
    response.raise_for_status()
    related_tag_infos = response.json()["related_tags"]

    # Select only tag names
    return list(map(lambda x: x["tag"]["name"], related_tag_infos))


def exclusive_filtering(related_tags: list[str], filters: list[str]) -> bool:
    """Filter tags by exclusive filtering
    TODO: Only sex filtering is implemented. More filterings are needed

    Example:
    related_tags = ["1boy", "1girl", ...]
    filters = ["1girl", ...]
    -> return False

    related_tags = ["1girl", "1other", ...]
    filters = ["1girl", ...]
    -> return True
    """
    sexes = {"1girl", "1boy", "1other"}
    for option_tags in [sexes]:
        selected_tag = [tag for tag in filters if tag in option_tags][0]
        for related_tag in related_tags:
            if related_tag in option_tags:
                if related_tag == selected_tag:
                    return True
                else:
                    return False
        else:
            return False


def filter_tags(tags: list[str], filters: list[str]) -> list[str]:
    """Filter tag information by filters"""
    if not filters:
        return tags

    filtered_tags = []
    for tag in tags:
        related_tags = get_related_tags(tag)
        if not exclusive_filtering(related_tags, filters):
            continue
        if any(tag not in related_tags for tag in filters):
            continue
        filtered_tags.append(tag)

    return filtered_tags


def clean_tags(tags: list[str]) -> list[str]:
    """Clean tag information for WebUI"""
    for idx, tag in enumerate(tags):
        tag = tag.replace("_", " ")
        tags[idx] = tag.replace("(", r"\(").replace(")", r"\)")
    return tags


def get_character_tags(
    copyrights: list[str],
    filters: list[str] = ["1girl"],
    n_characters: int = -1,
    allow_alternate_costume: bool = True,
) -> dict[list[str]]:
    """Get character tags from Danbooru webpage
    TODO: allow_alternate_costume
    """
    # Default value is infinite
    n_characters = inf if n_characters == -1 else n_characters

    result = {}
    for copyright in copyrights:
        character_tags = []

        page_no = 1
        while True:
            s_time = time()
            tags = get_tags(copyright, page_no)
            filtered_tags = filter_tags(tags, filters)
            cleaned_tags = clean_tags(filtered_tags)
            if not cleaned_tags:
                break
            character_tags.extend(filtered_tags)
            page_no += 1

            print(
                f"Elapsed time: {time() - s_time:.2f}s | Extracted tags: {filtered_tags}"
            )
            if len(character_tags) >= n_characters:
                break
        result[copyright] = character_tags
    return result


def save_wildcard(character_tags: dict, wildcards_dir: str) -> None:
    """Save character tags as a yaml file"""
    # Log result
    yaml_string = yaml.dump(
        {"characters": character_tags}, allow_unicode=True, sort_keys=False
    )
    print("# Characters")
    print(f"{100*'-'}\n{yaml_string}{100*'-'}")

    # Save result
    if wildcards_dir:
        makedirs(wildcards_dir, exist_ok=True)
        with open(CHARACTERS_WILDCARD_PATH, "r") as f:
            character_dict = yaml.safe_load(f)

        for copyright, tags in character_tags.items():
            updated_tags = character_dict["characters"].get(copyright, [])
            updated_tags.extend(tags)
            character_dict["characters"][copyright] = updated_tags

        with open(CHARACTERS_WILDCARD_PATH, "w") as f:
            yaml.safe_dump(character_dict, f)

# %%
character_tags = get_character_tags(
    copyrights=["blue_archive"], filters=["1girl"], n_characters=-1
)
save_wildcard(character_tags, wildcards_dir=WILDCARDS_DIR)

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta


def get_popular_tags(
    date: str | datetime | None = None,
    n_days: int = 1,
    n_images: int | None = None,
    n_pages: int = 1,
    wildcard_path: str | None = None,
) -> list[list[str]]:
    """Get tags of popular images in the date"""
    # Convert date to datetime object
    if date is None:
        # Yesterday is the latest data
        date = datetime.today() - relativedelta(day=1)
    elif isinstance(date, str):
        date = datetime.strptime(date, "%Y-%m-%d")

    tags_list = []

    for day in range(n_days):
        cur_date = (date - relativedelta(day=day)).strftime("%Y-%m-%d")
        page = 1
        while True:
            base_url = "https://danbooru.donmai.us/explore/posts/popular.json"
            queries = [
                f"date={cur_date}",
                f"page={page}",
                "scale=day",
            ]
            joined_query = "&".join(queries)
            url = f"{base_url}?{joined_query}"
            response = requests.get(url)
            response.raise_for_status()
            infos = response.json()

            for info in infos:
                cleaned_tags = (
                    info["tag_string"]
                    .replace(" ", ", ")
                    .replace("_", " ")
                    .replace("(", r"\(")
                    .replace(")", r"\)")
                )
                tags_list.append(cleaned_tags)

            if (n_images and len(tags_list) >= n_images) or (page > n_pages):
                break
            page += 1

        if wildcard_path:
            makedirs(dirname(wildcard_path), exist_ok=True)
            if exists(wildcard_path):
                with open(wildcard_path, "r") as f:
                    popular_dict = yaml.safe_load(f)
            else:
                popular_dict = {"popular": {}}

            popular_dict["popular"][date] = tags_list

            with open(wildcard_path, "w") as f:
                yaml.safe_dump(popular_dict, f)

        yaml_string = yaml.dump(
            {"popular": {cur_date: tags_list}}, allow_unicode=True, sort_keys=False
        )
        print("# Poplar")
        print(f"{100*'-'}\n{yaml_string}{100*'-'}")

    return popular_dict

# %%
popular = get_popular_tags(n_days=10, wildcard_path=POPULAR_WILDCARD_PATH)
# Out:
# # Poplar
# ----------------------------------------------------------------------------------------------------
# popular:
#   '2024-11-01':
#   - 1boy, 1girl, against wall, anal, animated, anus, ass, blue eyes, blue hair, clothed
#     female nude male, clothed sex, clothing aside, commentary, cum, cum in ass, cum
#     in pussy, cum overflow, dark-skinned male, dark skin, doggystyle, ejaculation,
#     english commentary, eyeliner, eyeshadow, finger in another's mouth, hair between
#     eyes, hair ornament, hairclip, hetero, makeup, nude, open mouth, original, paid
#     reward available, panties, panties aside, penis, pumpkin, pussy, saki \(the atko\),
#     sex, sex from behind, short hair, solo focus, sound, sound effects, squishsuccubus,
#     standing, standing sex, sweat, testicles, the atko, thong, thong aside, uncensored,
#     underwear, vaginal, video, voice actor
#   - 1girl, absurdres, alternate costume, anus, ass, ass cutout, black footwear, blue
#     eyes, blue hair, blue nails, clothing cutout, commentary, flat ass, hat, heart,
#     highres, hololive, hoshimachi suisei, hoshimachi suisei \(casual\), jacket, legs
#     up, merrytail, nail polish, official alternate costume, on floor, orange pantyhose,
#     pantyhose, presenting, presenting anus, presenting pussy, pussy, shoes, simple
#     background, skirt, solo, thick thighs, thighs, torn clothes, torn pantyhose, uncensored,
#     v, virtual youtuber, white background, wide hips
#   - 2girls, absurdres, anus, anus peek, ass, ass focus, black gloves, close-up, clothing
#     cutout, commentary, dokibird \(vtuber\), dokibird \(vtuber\) \(bounty hunter\),
#     dress, english commentary, female pov, frilled dress, frilled skirt, frills, from
#     behind, gloves, grabbing another's ass, groping, heart cutout, highres, indie
#     virtual youtuber, mint fantome, mint fantome \(minto 2.0\), mole, mole on ass,
#     mole on thigh, multiple girls, naokomama, panties, panty cutout, pov, pussy, pussy
#     peek, single thighhigh, skirt, solo focus, spread ass, spread pussy, spread pussy
#     under clothes, thigh gap, thigh strap, thighhighs, thighs, thong, torn clothes,
#     torn thighhighs, underwear, virtual youtuber, white panties, white thighhighs,
#     yuri
#   - 1boy, 1girl, alley, animated, assertive female, blush, breasts, censored, clothes
#     pull, collared shirt, commentary request, cosplay, cuffs, cum, cum on body, cum
#     on hands, ejaculation, enpitsunokaori, erection, faceless, faceless male, femdom,
#     fishnet thighhighs, fishnets, grin, halloween, handcuffs, handjob, hat, hetero,
#     large breasts, long hair, mosaic censoring, necktie, open mouth, original, outdoors,
#     paid reward available, pants, pants pull, peaked cap, penis, police, police uniform,
#     policewoman, public indecency, restrained, shirt, skirt, smile, steaming body,
#     sweat, thighhighs, ugoira
#   - 1girl, absurdres, animal ear fluff, animal ears, ass, backstage, bare shoulders,
#     black dress, black hairband, black hat, black pantyhose, blue archive, blue eyes,
#     blush, bow, cat ears, cat girl, commentary request, cowboy shot, dated commentary,
#     dress, earrings, extra ears, frilled dress, frills, from side, grey dress, hair
#     between eyes, hair intakes, hairband, halo, hat, highres, holding, holding microphone,
#     houkisei, jewelry, long hair, looking at viewer, low twintails, mari \(blue archive\),
#     mari \(idol\) \(blue archive\), microphone, midriff peek, mini hat, mini top hat,
#     official alternate costume, open mouth, orange hair, pantyhose, partial commentary,
#     sidelocks, solo, stud earrings, sweat, top hat, twintails, two-tone dress, wrist
#     wrap, yellow bow, yellow halo
#   - 1girl, absurdres, alternate costume, areola slip, black hair, black slingshot
#     swimsuit, blue archive, blush, breasts, bright pupils, collarbone, commentary
#     request, halo, highres, huge breasts, long hair, looking at viewer, mijikayo,
#     clothes, zenless zone zero
#   - 1girl, bare shoulders, black gloves, black leotard, black thighhighs, blue eyes,
#     blush, breasts, cleavage, cleavage cutout, clothing cutout, demon girl, demon
#     horns, demon tail, demon wings, elbow gloves, fate/grand order, fate \(series\),
#     fingerless gloves, gloves, grin, halloween costume, high heels, highres, horns,
#     large breasts, leotard, long hair, looking at viewer, miyamoto musashi \(fate\),
#     mugetsu2501, navel, pink hair, ponytail, smile, solo, swept bangs, tail, thighhighs,
#     wings
#   - 1girl, ayase momo, black choker, bra, bra lift, breasts, brown hair, choker, closed
#     mouth, clothes lift, commentary request, dandadan, earrings, facing viewer, floating
#     earring, head out of frame, highres, jewelry, large breasts, lifting own clothes,
#     morisobo, navel, nipples, one breast out, pink sweater, pleated skirt, school
#     uniform, shirt lift, short hair, simple background, skirt, solo, sweater, sweater
#     lift, underwear, white background, white bra
#   - 1boy, 1girl, arms behind back, bar censor, blush, breasts, brown hair, censored,
#     collarbone, commentary request, completely nude, cum, cum in mouth, cum on body,
#     cum on hair, cum on tongue, double bun, ejaculation, facial, from above, hair
#     bun, hand on own penis, highres, huge breasts, idolmaster, idolmaster shiny colors,
#     kneeling, looking at viewer, male masturbation, masturbation, nekoshoko, nipples,
#     nude, open mouth, penis, pink eyes, pov, producer \(idolmaster\), sanpaku, sitting,
#     solo focus, sonoda chiyoko, sweat, tongue, tongue out, two side up
#   - 1girl, all fours, anus, anus peek, ass, black panties, blue thighhighs, braid,
#     breasts, collarbone, commentary, from behind, green eyes, green hair, highres,
#     kanroji mitsuri, kimetsu no yaiba, large breasts, long hair, looking at viewer,
#     mole, mole under each eye, mole under eye, multicolored hair, multiple moles,
#     multiple views, panties, pink hair, purple background, shexyo, striped clothes,
#     striped thighhighs, thighhighs, thong, twin braids, two-tone hair, underwear,
#     vertical-striped clothes, vertical-striped thighhighs
#   - 1girl, absurdres, black choker, black hair, black thighhighs, blue archive, blush,
#     breasts, choker, earrings, elbow gloves, gloves, hair ornament, hairclip, hat,
#     highres, ichika \(blue archive\), jewelry, large breasts, long hair, looking at
#     viewer, navel, nipples, nude, open mouth, pussy, schwarz rubin, simple background,
#     solo, spread legs, stomach, thighhighs, tongue, tongue out, uncensored, white
#     background, witch hat
#   - 1boy, 1girl, ahoge, animal ears, animal hands, armpits, arms up, blonde hair,
#     blush, breasts, censored, collar, dog ears, dog tail, english commentary, erection,
#     fake animal ears, fang, flying sweatdrops, from above, gloves, heart, hetero,
#     long hair, looking at viewer, luciana de montefio, mosaic censoring, nipples,
#     nude, open mouth, orange eyes, paw gloves, penis, petite, side ponytail, signature,
#     small breasts, tail, thanabis, thighhighs, white thighhighs, zenless zone zero
#   - 1boy, 1girl, absurdres, all fours, ass, bar censor, blue eyes, blue hair, bottomless,
#     censored, deepthroat, erection, fellatio, hair ornament, hair ribbon, highres,
#     hololive, hoshimachi suisei, hoshimachi suisei \(1st costume\), long hair, looking
#     at viewer, nakano kura, no panties, oral, penis, ribbon, side ponytail, skirt,
#     socks, star \(symbol\), star in eye, symbol in eye, virtual youtuber
#     request, from above, gloves, grabbing another's breast, grabbing from behind,
#     groping, hair ornament, hairclip, hetero, large breasts, long hair, long sleeves,
#     lying, motion lines, nipples, on back, on bed, open mouth, original, paizuri,
#     pov, precum, purple eyes, sailor collar, school uniform, serafuku, shirt, shirt
#     lift, smile, solo focus, steaming body, straddling paizuri, toriatto gununu, underwear,
#     upper body, white bra
#   - 1girl, absurdres, alternate costume, animal ear fluff, animal ears, azur lane,
#     black choker, black pantyhose, black skirt, blush, breast rest, breasts, breasts
#     on table, cake, choker, cleavage, closed mouth, collarbone, commentary request,
#     crossed legs, facial mark, fingernails, flower, food, fox ears, fox girl, hair
#     flower, hair ornament, head rest, highres, large breasts, long hair, looking at
#     viewer, miniskirt, musashi \(azur lane\), nail polish, pantyhose, purple hair,
#     purple nails, qing wu, round table, shirt, sitting, skirt, smile, solo, table,
#     very long hair, whisker markings, white shirt, yellow eyes
#   - '1girl, absurdres, arms up, artist name, bikini, black bikini, blush, breasts,
#     cleavage, closed mouth, commentary, cosplay, ear piercing, elbow gloves, fate/grand
#     order, fate \(series\), feint721, from above, gloves, grey gloves, grey hair,
#     hair between eyes, highres, honkai: star rail, honkai \(series\), kemonomimi mode,
#     long hair, looking at viewer, mash kyrielight, mash kyrielight \(dangerous beast\),
#     mash kyrielight \(dangerous beast\) \(cosplay\), medium breasts, navel, orange
#     eyes, piercing, raccoon tail, solo, stelle \(honkai: star rail\), stomach, swimsuit,
#     tail, thigh strap, trailblazer \(honkai: star rail\), yellow eyes'
#   - 1girl, absurdres, bathroom, blush, breasts, brown eyes, brown hair, closed mouth,
#     commentary request, completely nude, cowboy shot, female masturbation, fingering,
#     grabbing own breast, highres, huyunokure, long hair, looking down, masturbation,
#     medium breasts, mirror, navel, nipples, nose blush, nude, original, pussy, reflection,
#     reflection focus, showering, soap bottle, solo, stomach, uncensored, water, wet
#   - 1girl, artist name, ass, black thighhighs, blonde hair, blush, breasts, burnice
#     white, cameltoe, commentary, crop top, english commentary, eyewear on head, fingernails,
#     hair between eyes, high-waist skirt, indoors, large breasts, long hair, lying,
#     mixed-language commentary, on back, oniilus, open mouth, panties, patreon username,
#     red-tinted eyewear, sidelocks, skirt, smile, solo, spread legs, sunglasses, teeth,
#     thighhighs, thighs, tinted eyewear, underwear, upper teeth only, variant set,
#     zenless zone zero
#   - 1girl, alternate costume, black choker, blue eyes, blush, breasts, cellphone,
#     choker, clothes lift, ear piercing, gloves, highres, holding, holding phone, hololive,
#     hoshimachi suisei, lifting own clothes, long hair, midriff, mirror, navel, nipple
#     piercing, nipples, partially fingerless gloves, phone, piercing, selfie, shirt
#     lift, small breasts, smartphone, solo, spot color, stomach, sunset skyline, taking
#     picture, tank top, virtual youtuber
#   - 1girl, ahoge, alisa mikhailovna kujou, black panties, black skirt, blue eyes,
#     breasts, cameltoe, choker, closed mouth, dakimakura \(medium\), feet, full body,
#     grey hair, groin, kneehighs, knees together feet apart, large breasts, legs, long
#     hair, looking at viewer, looking back, lying, miniskirt, multiple views, nipples,
#     smile, soles, solo, swept bangs, tail, thighs, toes, tomo0843, topless, tress
#     ribbon, underwear, virtual youtuber, white background, white panties, wings, yuzuki
#     choco
#   - 1girl, absurdres, ass visible through thighs, black panties, breasts, cameltoe,
#     close-up, colored pubic hair, high-waist skirt, highres, large breasts, long hair,
#     lower body, miniskirt, mole, mole on thigh, out of frame, panties, pantyshot,
#     pencil skirt, pink hair, pubic hair, shirt, skirt, solo, tsukishiro yanagi, underwear,
#     upskirt, valen \(valentineart\), white shirt, zenless zone zero
#   - 3girls, absurdres, animal ears, ass, bent over, black footwear, black gloves,
#     black skirt, blue skin, blurry, blurry background, blurry foreground, blush, breasts,
#     closed eyes, colored skin, desk, dress shirt, earrings, fox ears, furrowed brow,
#     glasses, gloves, hair between eyes, hanging breasts, high-waist skirt, high heels,
#     highres, hoshimi miyabi, huge breasts, jewelry, long hair, looking at another,
#     multiple girls, nokyang, oni, open mouth, out of frame, pencil skirt, pink eyes,
#     pink hair, shirt, sidelocks, skirt, solo focus, soukaku \(zenless zone zero\),
#     standing, sweatdrop, thighs, tsukishiro yanagi, white hair, white shirt, zenless
#     zone zero
#   - 1girl, absurdres, animal ear fluff, animal ears, animal hands, armpit crease,
#     atago \(azur lane\), atago \(full moon's feral wolf\) \(azur lane\), azur lane,
#     bare shoulders, bikini, black hair, black thighhighs, blush, brown gloves, brown
#     thighhighs, chinese commentary, closed mouth, commentary request, elbow gloves,
#     extra ears, fox tail, full moon, fur-trimmed bikini, fur trim, gloves, hair between
#     eyes, highres, l ract, lantern, long hair, looking at viewer, monster girl, moon,
#     night, night sky, official alternate costume, paper lantern, paw gloves, paw shoes,
#     single thighhigh, sky, solo, squatting, star \(sky\), starry sky, swimsuit, tail,
#     thighhighs, thighs, torii, torn clothes, torn thighhighs, werewolf costume, wolf
#     ears, wolf girl, yellow eyes
#   - 2boys, 2girls, aether \(genshin impact\), anal, ass, ass-to-ass, ass focus, belle
#     \(zenless zone zero\), blonde hair, blue hair, blush, bound, bound wrists, brother
#     and sister, company connection, femdom, flower, from behind, genshin impact, green
#     eyes, hair between eyes, hair flower, hair ornament, hetero, highres, huge ass,
#     incest, looking back, lumine \(genshin impact\), mihoyo, multiple boys, multiple
#     girls, nyantcha, pussy juice, short hair, short hair with long locks, siblings,
#     twins, wise \(zenless zone zero\), yellow eyes, zenless zone zero
#   - 2boys, 2girls, aki rosenthal, animal ears, ayunda risu, black thighhighs, blonde
#     hair, blush, bob cut, breasts, breath, brown hair, commentary, completely nude,
#     cum, cum on body, cum on legs, detached hair, ejaculation, english commentary,
#     green eyes, group sex, hand on another's hip, handjob, headgear, hetero, highres,
#     hololive, hololive indonesia, long hair, low twintails, medium breasts, multiple
#     boys, multiple girls, navel, nipples, nonstop nut november, nude, open mouth,
#     orgy, parted bangs, penis, purple eyes, short hair, simple background, sitting,
#     squirrel ears, squirrel girl, thigh sex, thighhighs, twintails, uncensored, virtual
#     youtuber, white background, yuyu5x
#   - '1girl, absurdres, anal fluid, anus, ass, back, blue eyes, blue hair, blush, breasts,
#     clothes, open mouth, panties, pink hair, pubic hair, simple background, solo,
#     stomach, twintails, underwear, white background, zenless zone zero
#   - 1boy, 1girl, against wall, animated, audible internal cumshot, audible speech,
#     blue eyes, blue hair, bouncing breasts, breasts, dawn \(pokemon\), flexible, hetero,
#     holding leg, leg hold, leg lift, leg up, medium breasts, navel, no headwear, nude,
#     okaimikey, penis, pokemon, pokemon dppt, sex, sex from behind, shiny skin, short
#     hair, solo focus, sound, split, spread legs, standing, standing on one leg, standing
#     sex, standing split, vaginal, video
#   - '1boy, 1girl, bed sheet, blue eyes, breasts, breasts out, censored, cinderella
#     \(nikke\), commentary request, covered navel, everydayangel, goddess of victory:
#     nikke, grabbing another''s arm, grey hair, hair over one eye, hetero, highres,
#     large breasts, long hair, lying, m legs, missionary, mosaic censoring, nipples,
#     on back, penis, pov, pussy, sex, sweat, twintails, vaginal, wince'
#   - 1boy, 2girls, :d, ahoge, all fours, animal ear fluff, animal ears, aqua bikini,
#     aqua eyes, artist logo, artist name, ass, beach, bikini, bikini bottom aside,
#     black hair, black jacket, blush, breasts, clothing aside, day, dr-alu, erection,
#     feet out of frame, fox ears, fox girl, fox tail, front-tie bikini top, front-tie
#     top, grey hair, hair intakes, hetero, hololive, hood, hood down, hooded jacket,
#     jacket, kneepits, logo, long hair, long sleeves, looking back, multicolored hair,
#     multiple girls, off shoulder, ookami mio, ookami mio \(hololive summer 2019\),
#     open clothes, open jacket, open mouth, outdoors, penis, red hair, sex, sex from
#     behind, shirakami fubuki, shirakami fubuki \(hololive summer 2019\), skindentation,
#     smile, streaked hair, swimsuit, tail, thigh strap, underboob, vaginal, virtual
#     youtuber, web address, white hair, white jacket, wolf girl
#   - 1boy, 1girl, bebatch, breasts, commentary request, completely nude, from side,
#     glasses, hand on another's knee, hetero, large breasts, long hair, looking at
#     another, missionary, nipples, nude, on chair, pink hair, purple eyes, sex, solo
#     focus, sweat, trembling, tsukishiro yanagi, zenless zone zero
#   - 1boy, 2girls, :d, ass, back, bar censor, bench, blue archive, blush, breasts,
#     censored, cleavage, collarbone, comic, crossed bangs, cum, demon tail, derivative
#     work, double-parted bangs, fang, fellatio, green hair, green halo, hair between
#     eyes, halo, handjob, hikari \(blue archive\), kneeling, licking, licking penis,
#     long hair, looking at penis, milkshakework, mosaic censoring, multiple girls,
#     nipples, no pants, no shirt, nozomi \(blue archive\), on bench, open mouth, oral,
#     orange eyes, pantyhose, penis, pointy ears, siblings, sidelocks, sisters ~natsu
#     no saigo no hi~, sitting, skin fang, small breasts, smile, smug, tail, teeth,
#     testicles, tongue, tongue out, train interior, twins, twintails, very long hair,
#     white pantyhose, window
#   - 1girl, absurdres, ass, ass focus, back, bent over, black pantyhose, chair, clothes
#     pull, commentary request, elf, facing away, frieren, from behind, grey background,
#     highres, legs together, long hair, long pointy ears, median furrow, pantyhose,
#     pantyhose pull, pointy ears, sattinittas, school chair, school uniform, shoulder
#     blades, solo, sousou no frieren, sweat, thong, topless, twintails, white hair
# ----------------------------------------------------------------------------------------------------
